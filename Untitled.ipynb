# %%
import numpy as np
import pandas as pd
import glob

# %%
pwd
# Out:
# u'/Users/talithaford/Dropbox/Conference-Workshop/ResBaz/2016/psychopy_lesson'

# %%
data_lst = glob.glob('data/*2016_Feb_02_*.csv')

# %%
data_lst
# Out:
# ['data/tf_visneuro_2016_Feb_02_1218.csv']

# %%
for i in data_lst:
    data = pd.read_csv(i).dropna(axis=1)
    print data.shape
# Out:
# (50, 15)

# %%
data_lst = glob.glob('data/*2016_Feb_02_*.csv')
frame = pd.DataFrame()
all_data = []
for data in data_lst:
    df = pd.read_csv(data,index_col=None, header=0).dropna(axis=1)
    if not df.shape == (50,15):
        continue
    print df.shape
    all_data.append(df)
    
frame = pd.concat(all_data)
frame.columns = ['correct_ans',
 'images',
 'type_of_image',
 'loop.thisRepN',
 'loop.thisTrialN',
 'loop.thisN',
 'loop.thisIndex',
 'key_resp.keys',
 'key_resp.corr',
 'key_resp.rt',
 'date',
 'frameRate',
 'expName',
 'session',
 'participant']
# Out:
# (50, 15)

# %%
frame
# Out:
#    correct_ans                       images type_of_image  loop.thisRepN  \
# 0         left      images/gorilla_fat.jpeg       gorilla              0
# 1        right    images/ear_muffs_cat.jpeg           cat              0
# 2        right         images/cat_eyes.jpeg           cat              0
# 3           up          images/egg_hog.jpeg           hog              0
# 4           up  images/marshmallow_hog.jpeg           hog              0
# 5        right          images/rat_cat.jpeg           cat              0
# 6           up        images/santa_hog.jpeg           hog              0
# 7           up     images/icecream_hog.jpeg           hog              0
# 8         left   images/gorilla_tongue.jpeg       gorilla              0
# 9         left     images/gorilla_face.jpeg       gorilla              0
# 10        left      images/gorilla_fat.jpeg       gorilla              1
# 11          up        images/santa_hog.jpeg           hog              1
# 12       right          images/rat_cat.jpeg           cat              1
# 13          up     images/icecream_hog.jpeg           hog              1
# 14        left   images/gorilla_tongue.jpeg       gorilla              1
# 15       right    images/ear_muffs_cat.jpeg           cat              1
# 16          up          images/egg_hog.jpeg           hog              1
# 17       right         images/cat_eyes.jpeg           cat              1
# 18          up  images/marshmallow_hog.jpeg           hog              1
# 19        left     images/gorilla_face.jpeg       gorilla              1
# 20          up  images/marshmallow_hog.jpeg           hog              2
# 21          up          images/egg_hog.jpeg           hog              2
# 22       right          images/rat_cat.jpeg           cat              2
# 23        left      images/gorilla_fat.jpeg       gorilla              2
# 24          up     images/icecream_hog.jpeg           hog              2
# 25       right         images/cat_eyes.jpeg           cat              2
# 26        left     images/gorilla_face.jpeg       gorilla              2
# 27        left   images/gorilla_tongue.jpeg       gorilla              2
# 28       right    images/ear_muffs_cat.jpeg           cat              2
# 29          up        images/santa_hog.jpeg           hog              2
# 30       right          images/rat_cat.jpeg           cat              3
# 31        left   images/gorilla_tongue.jpeg       gorilla              3
# 32          up        images/santa_hog.jpeg           hog              3
# 33          up  images/marshmallow_hog.jpeg           hog              3
# 34          up     images/icecream_hog.jpeg           hog              3
# 35        left      images/gorilla_fat.jpeg       gorilla              3
# 36       right    images/ear_muffs_cat.jpeg           cat              3
# 37          up          images/egg_hog.jpeg           hog              3
# 38        left     images/gorilla_face.jpeg       gorilla              3
# 39       right         images/cat_eyes.jpeg           cat              3
# 40          up          images/egg_hog.jpeg           hog              4
# 41       right         images/cat_eyes.jpeg           cat              4
# 42          up        images/santa_hog.jpeg           hog              4
# 43       right          images/rat_cat.jpeg           cat              4
# 44       right    images/ear_muffs_cat.jpeg           cat              4
# 45        left   images/gorilla_tongue.jpeg       gorilla              4
# 46        left     images/gorilla_face.jpeg       gorilla              4
# 47          up  images/marshmallow_hog.jpeg           hog              4
# 48          up     images/icecream_hog.jpeg           hog              4
# 49        left      images/gorilla_fat.jpeg       gorilla              4
#
#     loop.thisTrialN  loop.thisN  loop.thisIndex key_resp.keys  key_resp.corr  \
# 0                 0           0               1          left              1
# 1                 1           1               4         right              1
# 2                 2           2               3         right              1
# 3                 3           3               6            up              1
# 4                 4           4               8            up              1
# 5                 5           5               5         right              1
# 6                 6           6               9         right              0
# 7                 7           7               7            up              1
# 8                 8           8               2          left              1
# 9                 9           9               0          left              1
# 10                0          10               1          left              1
# 11                1          11               9            up              1
# 12                2          12               5         right              1
# 13                3          13               7            up              1
# 14                4          14               2          left              1
# 15                5          15               4         right              1
# 16                6          16               6            up              1
# 17                7          17               3         right              1
# 18                8          18               8          left              0
# 19                9          19               0          left              1
# 20                0          20               8            up              1
# 21                1          21               6            up              1
# 22                2          22               5         right              1
# 23                3          23               1          left              1
# 24                4          24               7            up              1
# 25                5          25               3         right              1
# 26                6          26               0          left              1
# 27                7          27               2          left              1
# 28                8          28               4         right              1
# 29                9          29               9            up              1
# 30                0          30               5            up              0
# 31                1          31               2          left              1
# 32                2          32               9            up              1
# 33                3          33               8            up              1
# 34                4          34               7            up              1
# 35                5          35               1          left              1
# 36                6          36               4         right              1
# 37                7          37               6            up              1
# 38                8          38               0          left              1
# 39                9          39               3         right              1
# 40                0          40               6            up              1
# 41                1          41               3         right              1
# 42                2          42               9            up              1
# 43                3          43               5         right              1
# 44                4          44               4            up              0
# 45                5          45               2          left              1
# 46                6          46               0          left              1
# 47                7          47               8            up              1
# 48                8          48               7            up              1
# 49                9          49               1          left              1
#
#     key_resp.rt              date  frameRate   expName  session participant
# 0      0.472581  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 1      0.600095  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 2      0.666623  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 3      0.600803  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 4      0.583730  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 5      0.549972  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 6      0.583965  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 7      0.616886  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 8      0.632353  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 9      0.517132  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 10     0.483761  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 11     0.650153  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 12     0.633529  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 13     1.015895  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 14     0.583656  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 15     0.633365  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 16     0.616708  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 17     0.749729  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 18     0.783000  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 19     0.648929  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 20     0.749856  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 21     0.616915  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 22     0.600387  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 23     0.732153  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 24     0.699889  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 25     0.749851  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 26     0.683387  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 27     0.633405  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 28     0.600264  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 29     0.782027  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 30     0.766520  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 31     0.999442  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 32     0.666694  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 33     0.849808  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 34     0.600168  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 35     0.633543  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 36     0.816443  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 37     1.148751  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 38     0.733305  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 39     0.683289  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 40     0.632192  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 41     1.033013  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 42     1.049431  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 43     0.550228  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 44     0.533877  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 45     0.810975  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 46     0.683441  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 47     0.700035  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 48     0.583618  2016_Feb_02_1218  60.185422  visneuro        1          tf
# 49     0.649955  2016_Feb_02_1218  60.185422  visneuro        1          tf
