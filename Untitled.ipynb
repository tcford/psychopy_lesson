# %%
import numpy as np
import pandas as pd
import glob

# %%
data = pd.read_csv('data/psychopy_TF_visneuro_2016_Feb_02_1105.csv')

# %%
data_lst = glob.glob('data/psychopy_TF_visneuro_2016_Feb_02_*.csv')

# %%
data_lst
# Out:
# ['data/psychopy_TF_visneuro_2016_Feb_02_1105.csv',
#  'data/psychopy_TF_visneuro_2016_Feb_02_1106.csv']
